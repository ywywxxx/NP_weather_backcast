# %%
import os
import requests
from time import sleep

from zoneinfo import ZoneInfo
from astral import LocationInfo
from astral.sun import sun
from datetime import datetime, time, date, timedelta

import os
import requests
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from time import sleep
from dateutil import parser
from dotenv import load_dotenv
import json

import numpy as np
from collections import defaultdict, Counter
import math

import drive

# %%
lat=latitude = '37.4277'
lon=longitude = '-122.1701'
USER_AGENT = {"User-Agent": "Pikachu"}
tzone= ZoneInfo("America/Los_Angeles")

# %%
# A single assumption event will generate 29 prediction entries and 2 real entries; 
assumption_date,assumption_index=drive.time_to_date_index( 
    datetime.now(tzone),lat, lon,tzone )

# %% [markdown]
# # Forecast

# %%
# Forecast: Probability, wind, humidity , overview 
hourlyForecast = drive.getHourlyForecast(latitude, longitude, USER_AGENT)

# %%
drive.time_to_date_index( 
    datetime.fromisoformat(hourlyForecast['properties']['generatedAt'])
    ,lat, lon,tzone
    )
# Out:
# (datetime.date(2026, 1, 5), 3)

# %%
groups = defaultdict(list)

for hour in hourlyForecast["properties"]["periods"]:
    dt = datetime.fromisoformat(hour["startTime"])  # aware
    d_local, idx = drive.time_to_date_index(dt, lat, lon, tzone)

    temp_c = (hour["temperature"] - 32) * 5 / 9
    pop = hour.get("probabilityOfPrecipitation", {}).get("value", None)

    # '7 mph' -> 7 -> km/h
    wind_kmh = float(hour["windSpeed"].split()[0]) * 1.60934

    groups[(d_local, idx)].append({
        "startTime": dt.astimezone(tzone),
        "temp_C": temp_c,
        "pop_pct": pop,
        "wind_kmh": wind_kmh,
        "wind_dir": hour.get("windDirection"),
        "forecast": hour.get("shortForecast"),
    })

# %%
def mode_or_none(values):
    vals = [v for v in values if v is not None]
    if not vals:
        return None
    return Counter(vals).most_common(1)[0][0]

# %%
grouped = []

for (d_local, idx), items in sorted(groups.items(), key=lambda x: (x[0][0], x[0][1])):
    temps = [it["temp_C"] for it in items]
    pops  = [it["pop_pct"] for it in items]
    winds = [it["wind_kmh"] for it in items]
    dirs  = [it["wind_dir"] for it in items]
    fcsts = [it["forecast"] for it in items]

    grouped.append({
        "date": d_local,
        "index": idx,
        
        "start_time": min(it["startTime"] for it in items),
        "end_time":  max(it["startTime"] for it in items)+ timedelta(hours=1),

        "temp_C_mean": np.mean(temps),
        "temp_C_min":  np.min(temps),
        "temp_C_max":  np.max(temps),

        "precipation": np.max(pops),

        "wind_kmh_mean": np.mean(winds),
        "wind_dir_mode": mode_or_none(dirs),
        "forecast_mode": mode_or_none(fcsts),
    })

# %% [markdown]
# # Raw Data

# %%
raw = drive.getOriginalData(latitude, longitude, USER_AGENT)

# %%
def build_grouped_from_values(values, field_name, *, lat, lon, tzone, drive, agg="mean"):
	groups = defaultdict(list)

	for hour in values:
		dt = datetime.fromisoformat(hour["validTime"].split("/")[0])  # aware
		d_local, idx = drive.time_to_date_index(dt, lat, lon, tzone)

		v = hour.get("value", None)
		groups[(d_local, idx)].append({
			"startTime": dt.astimezone(tzone),
			"value": v
		})

	grouped = []
	for (d_local, idx), items in sorted(groups.items(), key=lambda x: (x[0][0], x[0][1])):
		vals = np.array(
			[np.nan if it["value"] is None else float(it["value"]) for it in items],
			dtype=float
		)

		start_time = min(it["startTime"] for it in items)
		end_time   = max(it["startTime"] for it in items) + timedelta(hours=1)

		all_nan = (vals.size == 0) or np.all(np.isnan(vals))

		if agg == "sum":
			stat = float(np.nansum(vals)) if not all_nan else None
		elif agg == "mean":
			stat = float(np.nanmean(vals)) if not all_nan else None
		else:
			raise ValueError(f"agg must be 'mean' or 'sum', got {agg!r}")

		grouped.append({
			"date": d_local,
			"index": idx,
			"n_hours": len(items),
			"start_time": start_time,
			"end_time": end_time,
			f"{field_name}": stat,
		})

	return groups, grouped

# %%
groups_snowLevel, grouped_snowLevel = build_grouped_from_values(
	raw["properties"]["snowLevel"]["values"],
	"snowLevel",
	lat=lat, lon=lon, tzone=tzone, drive=drive, agg="mean"
)

groups_snowfallAmount, grouped_snowfallAmount = build_grouped_from_values(
	raw["properties"]["snowfallAmount"]["values"],
	"snowfallAmount",
	lat=lat, lon=lon, tzone=tzone, drive=drive, agg="sum"
)

groups_quantitativePrecipitation, grouped_quantitativePrecipitation = build_grouped_from_values(
	raw["properties"]["quantitativePrecipitation"]["values"],
	"quantitativePrecipitation",
	lat=lat, lon=lon, tzone=tzone, drive=drive, agg="sum"
)

groups_skyCover, grouped_skyCover = build_grouped_from_values(
	raw["properties"]["skyCover"]["values"],
	"skyCover",
	lat=lat, lon=lon, tzone=tzone, drive=drive, agg="mean"
)

groups_ice, grouped_ice = build_grouped_from_values(
	raw["properties"]["iceAccumulation"]["values"],
	"iceAccumulation",
	lat=lat, lon=lon, tzone=tzone, drive=drive, agg="mean"
)

# %%
def build_value_map(grouped_list, key_name: str):
	m = {}
	for row in grouped_list:
		m[(row["date"], row["index"])] = row.get(key_name, None)
	return m

sky_map     = build_value_map(grouped_skyCover, "skyCover")
snowlvl_map = build_value_map(grouped_snowLevel, "snowLevel")
snowamt_map = build_value_map(grouped_snowfallAmount, "snowfallAmount")
qpf_map     = build_value_map(grouped_quantitativePrecipitation, "quantitativePrecipitation")
ice_map     = build_value_map(grouped_ice, "iceAccumulation")


for row in grouped:
	key = (row["date"], row["index"])

	row["skyCover"] = sky_map.get(key, None)
	row["snowLevel"] = snowlvl_map.get(key, None)
	row["snowfallAmount"] = snowamt_map.get(key, None)
	row["quantitativePrecipitation"] = qpf_map.get(key, None)
	row["iceAccumulation"] = ice_map.get(key, None)

# %%
grouped
# Out:
# [{'date': datetime.date(2026, 1, 5),
#   'index': 3,
#   'n_hours': 1,
#   'start_time': datetime.datetime(2026, 1, 5, 23, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 6, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 10.555555555555555,
#   'temp_C_min': 10.555555555555555,
#   'temp_C_max': 10.555555555555555,
#   'pop_max': 53.0,
#   'wind_kmh_mean': 11.26538,
#   'wind_dir_mode': 'SE',
#   'shortForecast_mode': 'Chance Rain Showers',
#   'skyCover': 89.5,
#   'snowLevel': 1814.29152,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 1.015999977290622,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 6),
#   'index': 0,
#   'n_hours': 8,
#   'start_time': datetime.datetime(2026, 1, 6, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 6, 8, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 9.86111111111111,
#   'temp_C_min': 9.444444444444445,
#   'temp_C_max': 10.555555555555555,
#   'pop_max': 51.0,
#   'wind_kmh_mean': 6.839695,
#   'wind_dir_mode': 'SE',
#   'shortForecast_mode': 'Chance Rain Showers',
#   'skyCover': 75.85714285714286,
#   'snowLevel': 1865.55888,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.253999994322658,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 6),
#   'index': 1,
#   'n_hours': 5,
#   'start_time': datetime.datetime(2026, 1, 6, 8, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 6, 13, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 12.222222222222221,
#   'temp_C_min': 10.0,
#   'temp_C_max': 14.444444444444445,
#   'pop_max': 17.0,
#   'wind_kmh_mean': 4.184284000000001,
#   'wind_dir_mode': 'SE',
#   'shortForecast_mode': 'Partly Sunny',
#   'skyCover': 64.6,
#   'snowLevel': 1896.0592,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 6),
#   'index': 2,
#   'n_hours': 5,
#   'start_time': datetime.datetime(2026, 1, 6, 13, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 6, 18, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 14.666666666666666,
#   'temp_C_min': 13.88888888888889,
#   'temp_C_max': 15.0,
#   'pop_max': 6.0,
#   'wind_kmh_mean': 4.184284,
#   'wind_dir_mode': 'N',
#   'shortForecast_mode': 'Mostly Sunny',
#   'skyCover': 45.8,
#   'snowLevel': 1910.0292000000002,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 6),
#   'index': 3,
#   'n_hours': 6,
#   'start_time': datetime.datetime(2026, 1, 6, 18, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 7, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 10.833333333333334,
#   'temp_C_min': 10.0,
#   'temp_C_max': 12.777777777777779,
#   'pop_max': 8.0,
#   'wind_kmh_mean': 3.2186799999999995,
#   'wind_dir_mode': 'W',
#   'shortForecast_mode': 'Partly Cloudy',
#   'skyCover': 34.2,
#   'snowLevel': 1909.6481999999999,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 7),
#   'index': 0,
#   'n_hours': 8,
#   'start_time': datetime.datetime(2026, 1, 7, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 7, 8, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 8.819444444444445,
#   'temp_C_min': 8.333333333333334,
#   'temp_C_max': 9.444444444444445,
#   'pop_max': 11.0,
#   'wind_kmh_mean': 3.4198475000000004,
#   'wind_dir_mode': 'WSW',
#   'shortForecast_mode': 'Mostly Cloudy',
#   'skyCover': 76.33333333333333,
#   'snowLevel': 1767.9416,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 7),
#   'index': 1,
#   'n_hours': 5,
#   'start_time': datetime.datetime(2026, 1, 7, 8, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 7, 13, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 11.88888888888889,
#   'temp_C_min': 10.0,
#   'temp_C_max': 13.333333333333334,
#   'pop_max': 11.0,
#   'wind_kmh_mean': 7.402964,
#   'wind_dir_mode': 'NW',
#   'shortForecast_mode': 'Mostly Cloudy',
#   'skyCover': 77.0,
#   'snowLevel': 1591.9704,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 7),
#   'index': 2,
#   'n_hours': 5,
#   'start_time': datetime.datetime(2026, 1, 7, 13, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 7, 18, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 13.888888888888891,
#   'temp_C_min': 12.777777777777779,
#   'temp_C_max': 14.444444444444445,
#   'pop_max': 6.0,
#   'wind_kmh_mean': 14.48406,
#   'wind_dir_mode': 'NW',
#   'shortForecast_mode': 'Mostly Sunny',
#   'skyCover': 39.0,
#   'snowLevel': 1516.0752,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 7),
#   'index': 3,
#   'n_hours': 6,
#   'start_time': datetime.datetime(2026, 1, 7, 18, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 8, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 10.185185185185185,
#   'temp_C_min': 9.444444444444445,
#   'temp_C_max': 11.666666666666666,
#   'pop_max': 8.0,
#   'wind_kmh_mean': 13.947613333333331,
#   'wind_dir_mode': 'WNW',
#   'shortForecast_mode': 'Partly Cloudy',
#   'skyCover': 16.0,
#   'snowLevel': 1248.0036,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 8),
#   'index': 0,
#   'n_hours': 8,
#   'start_time': datetime.datetime(2026, 1, 8, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 8, 8, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 7.638888888888888,
#   'temp_C_min': 6.666666666666667,
#   'temp_C_max': 8.88888888888889,
#   'pop_max': 8.0,
#   'wind_kmh_mean': 10.661877500000001,
#   'wind_dir_mode': 'NW',
#   'shortForecast_mode': 'Mostly Clear',
#   'skyCover': 11.5,
#   'snowLevel': 1061.3135999999997,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 8),
#   'index': 1,
#   'n_hours': 5,
#   'start_time': datetime.datetime(2026, 1, 8, 8, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 8, 13, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 10.222222222222221,
#   'temp_C_min': 7.777777777777778,
#   'temp_C_max': 12.222222222222221,
#   'pop_max': 3.0,
#   'wind_kmh_mean': 10.621644,
#   'wind_dir_mode': 'NNW',
#   'shortForecast_mode': 'Sunny',
#   'skyCover': 15.0,
#   'snowLevel': 1015.8984,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 8),
#   'index': 2,
#   'n_hours': 5,
#   'start_time': datetime.datetime(2026, 1, 8, 13, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 8, 18, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 12.777777777777779,
#   'temp_C_min': 11.666666666666666,
#   'temp_C_max': 13.333333333333334,
#   'pop_max': 0.0,
#   'wind_kmh_mean': 14.48406,
#   'wind_dir_mode': 'NNW',
#   'shortForecast_mode': 'Sunny',
#   'skyCover': 10.0,
#   'snowLevel': 1043.94,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 8),
#   'index': 3,
#   'n_hours': 6,
#   'start_time': datetime.datetime(2026, 1, 8, 18, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 9, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 7.962962962962963,
#   'temp_C_min': 6.666666666666667,
#   'temp_C_max': 10.0,
#   'pop_max': 0.0,
#   'wind_kmh_mean': 9.924263333333334,
#   'wind_dir_mode': 'N',
#   'shortForecast_mode': 'Mostly Clear',
#   'skyCover': 9.5,
#   'snowLevel': 1103.9856,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 9),
#   'index': 0,
#   'n_hours': 8,
#   'start_time': datetime.datetime(2026, 1, 9, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 9, 8, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 4.861111111111111,
#   'temp_C_min': 3.888888888888889,
#   'temp_C_max': 6.111111111111111,
#   'pop_max': 0.0,
#   'wind_kmh_mean': 5.230355,
#   'wind_dir_mode': 'NNE',
#   'shortForecast_mode': 'Mostly Clear',
#   'skyCover': 36.0,
#   'snowLevel': 1162.7104,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 9),
#   'index': 1,
#   'n_hours': 5,
#   'start_time': datetime.datetime(2026, 1, 9, 8, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 9, 13, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 8.333333333333332,
#   'temp_C_min': 5.0,
#   'temp_C_max': 11.666666666666666,
#   'pop_max': 0.0,
#   'wind_kmh_mean': 6.759228,
#   'wind_dir_mode': 'NE',
#   'shortForecast_mode': 'Mostly Sunny',
#   'skyCover': 38.0,
#   'snowLevel': 1280.16,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 9),
#   'index': 2,
#   'n_hours': 5,
#   'start_time': datetime.datetime(2026, 1, 9, 13, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 9, 18, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 13.333333333333332,
#   'temp_C_min': 12.222222222222221,
#   'temp_C_max': 13.88888888888889,
#   'pop_max': 0.0,
#   'wind_kmh_mean': 9.012304,
#   'wind_dir_mode': 'NNE',
#   'shortForecast_mode': 'Sunny',
#   'skyCover': 5.0,
#   'snowLevel': 1416.1008000000002,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 9),
#   'index': 3,
#   'n_hours': 6,
#   'start_time': datetime.datetime(2026, 1, 9, 18, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 10, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 7.870370370370369,
#   'temp_C_min': 6.111111111111111,
#   'temp_C_max': 10.555555555555555,
#   'pop_max': 0.0,
#   'wind_kmh_mean': 5.364466666666668,
#   'wind_dir_mode': 'NE',
#   'shortForecast_mode': 'Clear',
#   'skyCover': 4.0,
#   'snowLevel': 1543.9644,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 10),
#   'index': 0,
#   'n_hours': 8,
#   'start_time': datetime.datetime(2026, 1, 10, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 10, 8, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 4.583333333333334,
#   'temp_C_min': 3.888888888888889,
#   'temp_C_max': 5.555555555555555,
#   'pop_max': 0.0,
#   'wind_kmh_mean': 4.82802,
#   'wind_dir_mode': 'E',
#   'shortForecast_mode': 'Mostly Clear',
#   'skyCover': 10.5,
#   'snowLevel': 1597.3552,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 10),
#   'index': 1,
#   'n_hours': 5,
#   'start_time': datetime.datetime(2026, 1, 10, 8, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 10, 13, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 9.11111111111111,
#   'temp_C_min': 5.555555555555555,
#   'temp_C_max': 12.777777777777779,
#   'pop_max': 0.0,
#   'wind_kmh_mean': 4.82802,
#   'wind_dir_mode': 'ENE',
#   'shortForecast_mode': 'Sunny',
#   'skyCover': 12.0,
#   'snowLevel': 1655.9784,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 10),
#   'index': 2,
#   'n_hours': 5,
#   'start_time': datetime.datetime(2026, 1, 10, 13, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 10, 18, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 14.333333333333332,
#   'temp_C_min': 13.333333333333334,
#   'temp_C_max': 15.0,
#   'pop_max': 0.0,
#   'wind_kmh_mean': 6.759228,
#   'wind_dir_mode': 'NNE',
#   'shortForecast_mode': 'Sunny',
#   'skyCover': 11.0,
#   'snowLevel': 1696.0596,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 10),
#   'index': 3,
#   'n_hours': 6,
#   'start_time': datetime.datetime(2026, 1, 10, 18, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 11, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 8.703703703703704,
#   'temp_C_min': 7.222222222222222,
#   'temp_C_max': 11.11111111111111,
#   'pop_max': 0.0,
#   'wind_kmh_mean': 4.023350000000001,
#   'wind_dir_mode': 'NE',
#   'shortForecast_mode': 'Mostly Clear',
#   'skyCover': 14.5,
#   'snowLevel': 1771.9548,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 11),
#   'index': 0,
#   'n_hours': 8,
#   'start_time': datetime.datetime(2026, 1, 11, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 11, 8, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 5.347222222222222,
#   'temp_C_min': 4.444444444444445,
#   'temp_C_max': 6.666666666666667,
#   'pop_max': 0.0,
#   'wind_kmh_mean': 4.023350000000001,
#   'wind_dir_mode': 'ENE',
#   'shortForecast_mode': 'Mostly Clear',
#   'skyCover': 21.0,
#   'snowLevel': 1812.036,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 11),
#   'index': 1,
#   'n_hours': 5,
#   'start_time': datetime.datetime(2026, 1, 11, 8, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 11, 13, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 9.666666666666668,
#   'temp_C_min': 6.111111111111111,
#   'temp_C_max': 13.333333333333334,
#   'pop_max': 0.0,
#   'wind_kmh_mean': 4.184284000000001,
#   'wind_dir_mode': 'NE',
#   'shortForecast_mode': 'Sunny',
#   'skyCover': 22.0,
#   'snowLevel': 1848.0024,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 11),
#   'index': 2,
#   'n_hours': 5,
#   'start_time': datetime.datetime(2026, 1, 11, 13, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 11, 18, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 15.11111111111111,
#   'temp_C_min': 14.444444444444445,
#   'temp_C_max': 15.555555555555555,
#   'pop_max': 0.0,
#   'wind_kmh_mean': 8.0467,
#   'wind_dir_mode': 'NNE',
#   'shortForecast_mode': 'Sunny',
#   'skyCover': 16.5,
#   'snowLevel': 1867.8144000000002,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 11),
#   'index': 3,
#   'n_hours': 6,
#   'start_time': datetime.datetime(2026, 1, 11, 18, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 12, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 9.537037037037038,
#   'temp_C_min': 7.777777777777778,
#   'temp_C_max': 12.222222222222221,
#   'pop_max': 1.0,
#   'wind_kmh_mean': 5.364466666666668,
#   'wind_dir_mode': 'N',
#   'shortForecast_mode': 'Partly Cloudy',
#   'skyCover': 34.5,
#   'snowLevel': 1883.9688,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 12),
#   'index': 0,
#   'n_hours': 8,
#   'start_time': datetime.datetime(2026, 1, 12, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 12, 8, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 6.388888888888889,
#   'temp_C_min': 5.555555555555555,
#   'temp_C_max': 7.777777777777778,
#   'pop_max': 1.0,
#   'wind_kmh_mean': 3.4198475000000004,
#   'wind_dir_mode': 'NE',
#   'shortForecast_mode': 'Partly Cloudy',
#   'skyCover': 42.666666666666664,
#   'snowLevel': 1880.0064,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 12),
#   'index': 1,
#   'n_hours': 3,
#   'start_time': datetime.datetime(2026, 1, 12, 8, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 12, 11, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 8.333333333333334,
#   'temp_C_min': 6.666666666666667,
#   'temp_C_max': 10.0,
#   'pop_max': 0.0,
#   'wind_kmh_mean': 3.755126666666667,
#   'wind_dir_mode': 'NE',
#   'shortForecast_mode': 'Mostly Sunny',
#   'skyCover': 25.0,
#   'snowLevel': 1912.0104,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0}]

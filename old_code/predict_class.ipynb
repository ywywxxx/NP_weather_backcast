# %%
import os
import requests
from time import sleep

from zoneinfo import ZoneInfo
from astral import LocationInfo
from astral.sun import sun
from datetime import datetime, time, date, timedelta

import os
import requests
# import matplotlib.dates as mdates
from time import sleep
from dateutil import parser
from dotenv import load_dotenv
import json

import numpy as np
from collections import defaultdict, Counter
import math

import old_code.drive as drive

from old_code.predict import WeatherPipeline

# %%
! pip install astral
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
lat=latitude = '37.4277'
lon=longitude = '-122.1701'
USER_AGENT = {"User-Agent": "Pikachu"}
tzone= ZoneInfo("America/Los_Angeles")

pipeline = WeatherPipeline(
    drive=drive,               
    lat=latitude,
    lon=longitude,
    tzone=tzone,
    user_agent=USER_AGENT
)

weathers=pipeline.run()

# %%
weathers
# Out:
# [{'date': datetime.date(2026, 1, 6),
#   'index': 2,
#   'n_hours': 3,
#   'start_time': datetime.datetime(2026, 1, 6, 15, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 6, 18, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'temp_C_mean': 15.185185185185185,
#   'temp_C_min': 14.444444444444445,
#   'temp_C_max': 15.555555555555555,
#   'pop_max': 8.0,
#   'wind_kmh_mean': 3.755126666666667,
#   'wind_dir_mode': 'NNW',
#   'shortForecast_mode': 'Mostly Sunny',
#   'skyCover': 42.5,
#   'snowLevel': 1883.9688,
#   'snowfallAmount': 0.0,
#   'quantitativePrecipitation': 0.0,
#   'iceAccumulation': 0.0},
#  {'date': datetime.date(2026, 1, 6),
#   'index': 3,
#   'n_hours': 6,
#   'start_time': datetime.datetime(2026, 1, 6, 18, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
#   'end_time': datetime.datetime(2026, 1, 7, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='America/Los_Angeles')),
# ...
